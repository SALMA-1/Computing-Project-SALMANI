# %%
from keras.models import Sequential,load_model
from keras.layers import Conv2D,Activation, MaxPooling2D,Dense,Flatten
from tensorflow.keras.optimizers import SGD
#from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

# %%
from sklearn.metrics import accuracy_score,roc_curve,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt_False_Positive_vs_True_Positive

# %%
def Build_CNN_Model():
    
    # -------------------------------------------------------------------------
    #                        Build CNN Model 
    # -------------------------------------------------------------------------
    model = Sequential()
    
    #  First Block of CNN
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=(224, 224, 3)))  
    model.add(Activation('relu'))
    model.add(MaxPooling2D((2, 2)))
    
    #  Second Block of CNN
    model.add(Conv2D(64, (3, 3),  padding='same'))  
    model.add(Activation('relu'))
    model.add(MaxPooling2D((2, 2)))

    #  Third Block of CNN
    model.add(Conv2D(128, (3, 3), padding='same'))  
    model.add(Activation('relu'))
    model.add(MaxPooling2D((2, 2)))  

    
    #  Flatten and Fully Connected Layer
    model.add(Flatten())
    model.add(Dense(1000))
    model.add(Activation('relu'))
     
    #  Softmax Classifier
    model.add(Dense(2))
    model.add(Activation('softmax'))
        
    #  Display model
    model.summary()
    
	# compile model
    opt = SGD(learning_rate=0.001)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# train and evalluate cnn model
def Train_CNN_Model(model):
    
    # -------------------------------------------------------------------------
    #                        Train CNN Model 
    # -------------------------------------------------------------------------
    
    # create data generators    
    train_datagen = ImageDataGenerator(
                                     rescale=1.0/255.0,
                                     featurewise_center= True,
                                     featurewise_std_normalization = True)
    
    valid_datagen = ImageDataGenerator(
                                     rescale=1.0/255.0,
                                     featurewise_center= True,
                                     featurewise_std_normalization = True)
    
   
   
    # prepare iterators
    batch_size=32
    train_it = train_datagen.flow_from_directory('Data/train/',classes =('normal','abnormal'),batch_size=batch_size, target_size=(224, 224))
    valid_it = valid_datagen.flow_from_directory('Data/val/',classes =('normal','abnormal'),batch_size=batch_size, target_size=(224, 224))


    epochs=100;
    
    history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
		validation_data=valid_it, validation_steps=len(valid_it), epochs=epochs, verbose=1)
    
    
    #  "Accuracy"
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
    # "Loss"
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

	# save model
    model.save('medical_diagnosis_cnn_model.h5')

# %%
def Evaluate_CNN_Model():
    # -------------------------------------------------------------------------
    #                        Evaluate CNN Model 
    # -------------------------------------------------------------------------
    
    # load model
    model = load_model('medical_diagnosis_cnn_model.h5')
    
    # load test data
    batch_size=32
    test_datagen = ImageDataGenerator(
                                     rescale=1.0/255.0,
                                     featurewise_center= True,
                                     featurewise_std_normalization = True)
    
    test_it = test_datagen.flow_from_directory('Data/test/',classes =('normal','abnormal'), 
                                               shuffle=False,batch_size=batch_size, target_size=(224, 224))
    
    y_true = test_it.classes;

    y_pred = model.predict_generator(test_it, steps=len(test_it), verbose=1)

    
    y_pred_prob = y_pred[:,1]

     
    y_pred_binary =  y_pred_prob > 0.5
   
    #Confution Matrix    
    print('\nConfusion Matrix\n -------------------------')    
    print(confusion_matrix(y_true,y_pred_binary));
    
    # accuracy: (tp + tn) / (p + n)
    accuracy = accuracy_score(y_true, y_pred_binary)
    print('Accuracy: %f' % accuracy)
    
    
    # precision tp / (tp + fp)
    precision = precision_score(y_true, y_pred_binary)
    print('Precision: %f' % precision)
    
    # recall: tp / (tp + fn)
    recall = recall_score(y_true, y_pred_binary)
    print('Recall: %f' % recall)
    
    # f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(y_true, y_pred_binary)
    print('F1 score: %f' % f1)    
       
    # ROC AUC
    auc = roc_auc_score(y_true, y_pred_prob)
    print('ROC AUC: %f' % auc)
    
    
    # calculate roc curves
    fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
        
    # plot the roc curve for the model
    plt.figure()
    plt_False_Positive_vs_True_Positive.plot(fpr, tpr, linestyle='--', label='')
    
    # axis labels
    plt_False_Positive_vs_True_Positive.xlabel('False Positive Rate')
    plt_False_Positive_vs_True_Positive.ylabel('True Positive Rate')
       
    # show the legend
    plt_False_Positive_vs_True_Positive.legend()
    # show the plot
    plt_False_Positive_vs_True_Positive.show()

# %%
# main entry
    
model = Build_CNN_Model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  activation (Activation)     (None, 224, 224, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  activation_1 (Activation)   (None, 112, 112, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  activation_2 (Activation)   (None, 56, 56, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 1000)              100353000
#
#  activation_3 (Activation)   (None, 1000)              0
#
#  dense_1 (Dense)             (None, 2)                 2002
#
#  activation_4 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 100,448,250
# Trainable params: 100,448,250
# Non-trainable params: 0
# _________________________________________________________________

# %%
Train_CNN_Model(model)
# Out:
# Found 600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# C:\Users\STUDEN~1\AppData\Local\Temp/ipykernel_14408/4231913677.py:29: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
# Epoch 1/100
# 19/19 [==============================] - 62s 3s/step - loss: 0.4612 - accuracy: 0.8883 - val_loss: 0.4676 - val_accuracy: 0.8850
# Epoch 2/100
# 19/19 [==============================] - 64s 3s/step - loss: 0.4381 - accuracy: 0.8883 - val_loss: 0.4475 - val_accuracy: 0.8900
# Epoch 3/100
# 19/19 [==============================] - 66s 3s/step - loss: 0.4136 - accuracy: 0.8867 - val_loss: 0.4291 - val_accuracy: 0.8800
# Epoch 4/100
# 19/19 [==============================] - 66s 4s/step - loss: 0.3897 - accuracy: 0.9017 - val_loss: 0.4411 - val_accuracy: 0.8075
# Epoch 5/100
# 19/19 [==============================] - 67s 4s/step - loss: 0.3805 - accuracy: 0.8833 - val_loss: 0.3917 - val_accuracy: 0.8875
# Epoch 6/100
# 19/19 [==============================] - 60s 3s/step - loss: 0.3510 - accuracy: 0.9017 - val_loss: 0.3975 - val_accuracy: 0.8375
# Epoch 7/100
# 19/19 [==============================] - 62s 3s/step - loss: 0.3351 - accuracy: 0.9067 - val_loss: 0.3683 - val_accuracy: 0.8675
# Epoch 8/100
# 19/19 [==============================] - 54s 3s/step - loss: 0.3168 - accuracy: 0.9100 - val_loss: 0.3479 - val_accuracy: 0.8825
# Epoch 9/100
# 19/19 [==============================] - 68s 4s/step - loss: 0.2918 - accuracy: 0.9100 - val_loss: 0.3374 - val_accuracy: 0.8700
# Epoch 10/100
# 19/19 [==============================] - 56s 3s/step - loss: 0.2827 - accuracy: 0.9083 - val_loss: 0.3551 - val_accuracy: 0.8300
# Epoch 11/100
# 19/19 [==============================] - 57s 3s/step - loss: 0.2613 - accuracy: 0.9217 - val_loss: 0.3412 - val_accuracy: 0.8375
# Epoch 12/100
# 19/19 [==============================] - 58s 3s/step - loss: 0.2510 - accuracy: 0.9167 - val_loss: 0.2983 - val_accuracy: 0.9025
# Epoch 13/100
# 19/19 [==============================] - 58s 3s/step - loss: 0.2381 - accuracy: 0.9167 - val_loss: 0.2975 - val_accuracy: 0.8900
# Epoch 14/100
# 19/19 [==============================] - 67s 4s/step - loss: 0.2534 - accuracy: 0.8983 - val_loss: 0.2872 - val_accuracy: 0.8900
# Epoch 15/100
# 19/19 [==============================] - 60s 3s/step - loss: 0.2185 - accuracy: 0.9233 - val_loss: 0.3052 - val_accuracy: 0.8575
# Epoch 16/100
# 19/19 [==============================] - 63s 3s/step - loss: 0.2220 - accuracy: 0.9267 - val_loss: 0.2679 - val_accuracy: 0.9075
# Epoch 17/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.2047 - accuracy: 0.9333 - val_loss: 0.3359 - val_accuracy: 0.8200
# Epoch 18/100
# 19/19 [==============================] - 63s 3s/step - loss: 0.2776 - accuracy: 0.8850 - val_loss: 0.2828 - val_accuracy: 0.8775
# Epoch 19/100
# 19/19 [==============================] - 60s 3s/step - loss: 0.2040 - accuracy: 0.9200 - val_loss: 0.2578 - val_accuracy: 0.8975
# Epoch 20/100
# 19/19 [==============================] - 57s 3s/step - loss: 0.2565 - accuracy: 0.8883 - val_loss: 0.6209 - val_accuracy: 0.7175
# Epoch 21/100
# 19/19 [==============================] - 58s 3s/step - loss: 0.2220 - accuracy: 0.9133 - val_loss: 0.2435 - val_accuracy: 0.9075
# Epoch 22/100
# 19/19 [==============================] - 57s 3s/step - loss: 0.1751 - accuracy: 0.9383 - val_loss: 0.4077 - val_accuracy: 0.8000
# Epoch 23/100
# 19/19 [==============================] - 59s 3s/step - loss: 0.2058 - accuracy: 0.9117 - val_loss: 0.2741 - val_accuracy: 0.8625
# Epoch 24/100
# 19/19 [==============================] - 67s 4s/step - loss: 0.1763 - accuracy: 0.9417 - val_loss: 0.2387 - val_accuracy: 0.9075
# Epoch 25/100
# 19/19 [==============================] - 61s 3s/step - loss: 0.2072 - accuracy: 0.9150 - val_loss: 0.2713 - val_accuracy: 0.8750
# Epoch 26/100
# 19/19 [==============================] - 58s 3s/step - loss: 0.1925 - accuracy: 0.9183 - val_loss: 0.2747 - val_accuracy: 0.8650
# Epoch 27/100
# 19/19 [==============================] - 63s 3s/step - loss: 0.1425 - accuracy: 0.9500 - val_loss: 0.2430 - val_accuracy: 0.8975
# Epoch 28/100
# 19/19 [==============================] - 64s 3s/step - loss: 0.1549 - accuracy: 0.9450 - val_loss: 0.2176 - val_accuracy: 0.9225
# Epoch 29/100
# 19/19 [==============================] - 61s 3s/step - loss: 0.2201 - accuracy: 0.9100 - val_loss: 0.2363 - val_accuracy: 0.8975
# Epoch 30/100
# 19/19 [==============================] - 61s 3s/step - loss: 0.1899 - accuracy: 0.9317 - val_loss: 0.3483 - val_accuracy: 0.8200
# Epoch 31/100
# 19/19 [==============================] - 58s 3s/step - loss: 0.1983 - accuracy: 0.9233 - val_loss: 0.2337 - val_accuracy: 0.9075
# Epoch 32/100
# 19/19 [==============================] - 56s 3s/step - loss: 0.1845 - accuracy: 0.9333 - val_loss: 0.3167 - val_accuracy: 0.8400
# Epoch 33/100
# 19/19 [==============================] - 65s 3s/step - loss: 0.1813 - accuracy: 0.9317 - val_loss: 0.2549 - val_accuracy: 0.8850
# Epoch 34/100
# 19/19 [==============================] - 60s 3s/step - loss: 0.1355 - accuracy: 0.9500 - val_loss: 0.2010 - val_accuracy: 0.9225
# Epoch 35/100
# 19/19 [==============================] - 60s 3s/step - loss: 0.1543 - accuracy: 0.9417 - val_loss: 0.2411 - val_accuracy: 0.9000
# Epoch 36/100
# 19/19 [==============================] - 76s 4s/step - loss: 0.1364 - accuracy: 0.9467 - val_loss: 0.2023 - val_accuracy: 0.9125
# Epoch 37/100
# 19/19 [==============================] - 67s 4s/step - loss: 0.1201 - accuracy: 0.9583 - val_loss: 0.2202 - val_accuracy: 0.9000
# Epoch 38/100
# 19/19 [==============================] - 72s 4s/step - loss: 0.1176 - accuracy: 0.9617 - val_loss: 0.1975 - val_accuracy: 0.9275
# Epoch 39/100
# 19/19 [==============================] - 62s 3s/step - loss: 0.2485 - accuracy: 0.9200 - val_loss: 0.2365 - val_accuracy: 0.9000
# Epoch 40/100
# 19/19 [==============================] - 60s 3s/step - loss: 0.1282 - accuracy: 0.9583 - val_loss: 0.2113 - val_accuracy: 0.9050
# Epoch 41/100
# 19/19 [==============================] - 61s 3s/step - loss: 0.1350 - accuracy: 0.9467 - val_loss: 0.1939 - val_accuracy: 0.9250
# Epoch 42/100
# 19/19 [==============================] - 65s 3s/step - loss: 0.1281 - accuracy: 0.9633 - val_loss: 0.1903 - val_accuracy: 0.9275
# Epoch 43/100
# 19/19 [==============================] - 90s 5s/step - loss: 0.1214 - accuracy: 0.9600 - val_loss: 0.2168 - val_accuracy: 0.9000
# Epoch 44/100
# 19/19 [==============================] - 77s 4s/step - loss: 0.0999 - accuracy: 0.9717 - val_loss: 0.1973 - val_accuracy: 0.9050
# Epoch 45/100
# 19/19 [==============================] - 78s 4s/step - loss: 0.1079 - accuracy: 0.9633 - val_loss: 0.1890 - val_accuracy: 0.9175
# Epoch 46/100
# 19/19 [==============================] - 76s 4s/step - loss: 0.1214 - accuracy: 0.9600 - val_loss: 0.1870 - val_accuracy: 0.9150
# Epoch 47/100
# 19/19 [==============================] - 88s 5s/step - loss: 0.2295 - accuracy: 0.9033 - val_loss: 0.1874 - val_accuracy: 0.9125
# Epoch 48/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.1144 - accuracy: 0.9600 - val_loss: 0.1925 - val_accuracy: 0.9075
# Epoch 49/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.1301 - accuracy: 0.9467 - val_loss: 0.1892 - val_accuracy: 0.9125
# Epoch 50/100
# 19/19 [==============================] - 77s 4s/step - loss: 0.1502 - accuracy: 0.9450 - val_loss: 0.1814 - val_accuracy: 0.9275
# Epoch 51/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.1416 - accuracy: 0.9400 - val_loss: 0.2091 - val_accuracy: 0.9100
# Epoch 52/100
# 19/19 [==============================] - 68s 4s/step - loss: 0.0934 - accuracy: 0.9717 - val_loss: 0.2114 - val_accuracy: 0.9075
# Epoch 53/100
# 19/19 [==============================] - 61s 3s/step - loss: 0.0951 - accuracy: 0.9667 - val_loss: 0.2216 - val_accuracy: 0.9075
# Epoch 54/100
# 19/19 [==============================] - 64s 3s/step - loss: 0.1014 - accuracy: 0.9667 - val_loss: 0.1787 - val_accuracy: 0.9275
# Epoch 55/100
# 19/19 [==============================] - 57s 3s/step - loss: 0.1008 - accuracy: 0.9633 - val_loss: 0.1774 - val_accuracy: 0.9300
# Epoch 56/100
# 19/19 [==============================] - 61s 3s/step - loss: 0.1390 - accuracy: 0.9400 - val_loss: 0.3096 - val_accuracy: 0.8675
# Epoch 57/100
# 19/19 [==============================] - 57s 3s/step - loss: 0.0953 - accuracy: 0.9633 - val_loss: 0.2147 - val_accuracy: 0.9100
# Epoch 58/100
# 19/19 [==============================] - 54s 3s/step - loss: 0.2300 - accuracy: 0.9150 - val_loss: 0.2009 - val_accuracy: 0.9275
# Epoch 59/100
# 19/19 [==============================] - 54s 3s/step - loss: 0.1077 - accuracy: 0.9600 - val_loss: 0.2193 - val_accuracy: 0.9050
# Epoch 60/100
# 19/19 [==============================] - 76s 4s/step - loss: 0.0887 - accuracy: 0.9683 - val_loss: 0.1742 - val_accuracy: 0.9300
# Epoch 61/100
# 19/19 [==============================] - 76s 4s/step - loss: 0.0876 - accuracy: 0.9717 - val_loss: 0.2725 - val_accuracy: 0.8750
# Epoch 62/100
# 19/19 [==============================] - 63s 3s/step - loss: 0.1115 - accuracy: 0.9550 - val_loss: 0.1976 - val_accuracy: 0.9275
# Epoch 63/100
# 19/19 [==============================] - 64s 3s/step - loss: 0.1749 - accuracy: 0.9267 - val_loss: 0.2121 - val_accuracy: 0.9075
# Epoch 64/100
# 19/19 [==============================] - 63s 3s/step - loss: 0.1625 - accuracy: 0.9300 - val_loss: 0.1714 - val_accuracy: 0.9300
# Epoch 65/100
# 19/19 [==============================] - 68s 4s/step - loss: 0.0881 - accuracy: 0.9700 - val_loss: 0.2509 - val_accuracy: 0.8800
# Epoch 66/100
# 19/19 [==============================] - 67s 4s/step - loss: 0.1601 - accuracy: 0.9283 - val_loss: 0.1792 - val_accuracy: 0.9200
# Epoch 67/100
# 19/19 [==============================] - 57s 3s/step - loss: 0.1184 - accuracy: 0.9500 - val_loss: 0.4903 - val_accuracy: 0.8050
# Epoch 68/100
# 19/19 [==============================] - 58s 3s/step - loss: 0.1753 - accuracy: 0.9300 - val_loss: 0.2075 - val_accuracy: 0.9125
# Epoch 69/100
# 19/19 [==============================] - 56s 3s/step - loss: 0.0784 - accuracy: 0.9733 - val_loss: 0.1710 - val_accuracy: 0.9375
# Epoch 70/100
# 19/19 [==============================] - 66s 3s/step - loss: 0.1129 - accuracy: 0.9483 - val_loss: 0.3151 - val_accuracy: 0.8725
# Epoch 71/100
# 19/19 [==============================] - 66s 3s/step - loss: 0.0891 - accuracy: 0.9650 - val_loss: 0.1814 - val_accuracy: 0.9200
# Epoch 72/100
# 19/19 [==============================] - 69s 4s/step - loss: 0.0761 - accuracy: 0.9750 - val_loss: 0.1695 - val_accuracy: 0.9300
# Epoch 73/100
# 19/19 [==============================] - 63s 3s/step - loss: 0.1137 - accuracy: 0.9517 - val_loss: 0.1720 - val_accuracy: 0.9250
# Epoch 74/100
# 19/19 [==============================] - 58s 3s/step - loss: 0.1227 - accuracy: 0.9600 - val_loss: 0.1702 - val_accuracy: 0.9375
# Epoch 75/100
# 19/19 [==============================] - 89s 5s/step - loss: 0.0877 - accuracy: 0.9717 - val_loss: 0.1710 - val_accuracy: 0.9375
# Epoch 76/100
# 19/19 [==============================] - 81s 4s/step - loss: 0.0819 - accuracy: 0.9717 - val_loss: 0.2298 - val_accuracy: 0.9025
# Epoch 77/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.1033 - accuracy: 0.9617 - val_loss: 0.3409 - val_accuracy: 0.8700
# Epoch 78/100
# 19/19 [==============================] - 81s 4s/step - loss: 0.0801 - accuracy: 0.9733 - val_loss: 0.1927 - val_accuracy: 0.9150
# Epoch 79/100
# 19/19 [==============================] - 81s 4s/step - loss: 0.0732 - accuracy: 0.9783 - val_loss: 0.1688 - val_accuracy: 0.9375
# Epoch 80/100
# 19/19 [==============================] - 78s 4s/step - loss: 0.0818 - accuracy: 0.9683 - val_loss: 0.1763 - val_accuracy: 0.9325
# Epoch 81/100
# 19/19 [==============================] - 76s 4s/step - loss: 0.1045 - accuracy: 0.9600 - val_loss: 0.5059 - val_accuracy: 0.8325
# Epoch 82/100
# 19/19 [==============================] - 78s 4s/step - loss: 0.0943 - accuracy: 0.9650 - val_loss: 0.2237 - val_accuracy: 0.9025
# Epoch 83/100
# 19/19 [==============================] - 78s 4s/step - loss: 0.1096 - accuracy: 0.9467 - val_loss: 0.1705 - val_accuracy: 0.9375
# Epoch 84/100
# 19/19 [==============================] - 78s 4s/step - loss: 0.0778 - accuracy: 0.9700 - val_loss: 0.1697 - val_accuracy: 0.9375
# Epoch 85/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.0847 - accuracy: 0.9700 - val_loss: 0.1695 - val_accuracy: 0.9375
# Epoch 86/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.4010 - accuracy: 0.8883 - val_loss: 0.1896 - val_accuracy: 0.9150
# Epoch 87/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.0685 - accuracy: 0.9750 - val_loss: 0.1995 - val_accuracy: 0.9150
# Epoch 88/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.0768 - accuracy: 0.9683 - val_loss: 0.1917 - val_accuracy: 0.9175
# Epoch 89/100
# 19/19 [==============================] - 77s 4s/step - loss: 0.0739 - accuracy: 0.9783 - val_loss: 0.1697 - val_accuracy: 0.9375
# Epoch 90/100
# 19/19 [==============================] - 85s 4s/step - loss: 0.0669 - accuracy: 0.9783 - val_loss: 0.1821 - val_accuracy: 0.9175
# Epoch 91/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.0682 - accuracy: 0.9733 - val_loss: 0.1694 - val_accuracy: 0.9375
# Epoch 92/100
# 19/19 [==============================] - 86s 5s/step - loss: 0.0732 - accuracy: 0.9733 - val_loss: 0.1813 - val_accuracy: 0.9125
# Epoch 93/100
# 19/19 [==============================] - 78s 4s/step - loss: 0.0618 - accuracy: 0.9833 - val_loss: 0.2078 - val_accuracy: 0.9100
# Epoch 94/100
# 19/19 [==============================] - 88s 5s/step - loss: 0.0644 - accuracy: 0.9833 - val_loss: 0.1725 - val_accuracy: 0.9275
# Epoch 95/100
# 19/19 [==============================] - 81s 4s/step - loss: 0.0584 - accuracy: 0.9833 - val_loss: 0.1684 - val_accuracy: 0.9300
# Epoch 96/100
# 19/19 [==============================] - 87s 5s/step - loss: 0.0702 - accuracy: 0.9733 - val_loss: 0.1714 - val_accuracy: 0.9375
# Epoch 97/100
# 19/19 [==============================] - 83s 4s/step - loss: 0.0870 - accuracy: 0.9667 - val_loss: 0.1751 - val_accuracy: 0.9250
# Epoch 98/100
# 19/19 [==============================] - 84s 4s/step - loss: 0.0737 - accuracy: 0.9717 - val_loss: 0.1797 - val_accuracy: 0.9225
# Epoch 99/100
# 19/19 [==============================] - 59s 3s/step - loss: 0.0659 - accuracy: 0.9767 - val_loss: 0.1753 - val_accuracy: 0.9275
# Epoch 100/100
# 19/19 [==============================] - 53s 3s/step - loss: 0.0596 - accuracy: 0.9733 - val_loss: 0.1751 - val_accuracy: 0.9250

# %%
Evaluate_CNN_Model()
# Out:
# Found 624 images belonging to 2 classes.
# C:\Users\STUDEN~1\AppData\Local\Temp/ipykernel_14408/1142865307.py:21: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(test_it, steps=len(test_it), verbose=1)
# 20/20 [==============================] - 20s 971ms/step
# No handles with labels found to put in legend.
# Confusion Matrix
#  -------------------------
# [[126 108]
#  [ 11 379]]
# Accuracy: 0.809295
# Precision: 0.778234
# Recall: 0.971795
# F1 score: 0.864310
# ROC AUC: 0.926759

# %%
m=[[126, 108],
 [ 11, 379]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.heatmap(m, annot=True, cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()
