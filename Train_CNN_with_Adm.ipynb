# %%
from keras.models import Sequential,load_model
from keras.layers import Conv2D,Activation, MaxPooling2D,Dense,Flatten
#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import accuracy_score,roc_curve,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt_False_Positive_vs_True_Positive

# %%
def Build_CNN_Model():
    
    # -------------------------------------------------------------------------
    #                        Build CNN Model 
    # -------------------------------------------------------------------------
    model = Sequential()
    
    #  First Block of CNN
    model.add(Conv2D(8, (5, 5), padding='same', input_shape=(224, 224, 3)))  
    model.add(Activation('relu'))
    model.add(MaxPooling2D((2, 2)))
    
    #  Second Block of CNN
    model.add(Conv2D(8, (3, 3),  padding='same'))  
    model.add(Activation('relu'))
    model.add(MaxPooling2D((2, 2)))

    #  Third Block of CNN
    model.add(Conv2D(16, (3, 3),  padding='same'))  
    model.add(Activation('relu'))


    #  Forth Block of CNN
    model.add(Conv2D(16, (3, 3),  padding='same'))  
    model.add(Activation('relu'))
    model.add(MaxPooling2D((2, 2)))

    
    #  Flatten and Fully Connected Layer
    model.add(Flatten())
    model.add(Dense(10))
    model.add(Activation('relu'))
     
    #  Softmax Classifier
    model.add(Dense(2))
    model.add(Activation('softmax'))
        
    #  Display model
    model.summary()
    
	# compile model

    opt = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# train and evalluate cnn model
def Train_CNN_Model(model):
    
    # -------------------------------------------------------------------------
    #                        Train CNN Model 
    # -------------------------------------------------------------------------
    
    # create data generators    
    train_datagen = ImageDataGenerator(
                                     rescale=1.0/255.0,
                                     featurewise_center= True,
                                     featurewise_std_normalization = True)
    
    valid_datagen = ImageDataGenerator(
                                     rescale=1.0/255.0,
                                     featurewise_center= True,
                                     featurewise_std_normalization = True)
    
   
   
    # prepare iterators
    batch_size=32
    train_it = train_datagen.flow_from_directory('Data/train/',classes =('normal','abnormal'),batch_size=batch_size, target_size=(224, 224))
    valid_it = valid_datagen.flow_from_directory('Data/val/',classes =('normal','abnormal'),batch_size=batch_size, target_size=(224, 224))


    epochs=100;
    
    history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
		validation_data=valid_it, validation_steps=len(valid_it), epochs=epochs, verbose=1)
    
    
    #  "Accuracy"
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
    # "Loss"
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

	# save model
    model.save('medical_diagnosis_cnn_model.h5')

# %%
def Evaluate_CNN_Model():
    # -------------------------------------------------------------------------
    #                        Evaluate CNN Model 
    # -------------------------------------------------------------------------
    
    # load model
    model = load_model('medical_diagnosis_cnn_model.h5')
    
    # load test data
    batch_size=32
    test_datagen = ImageDataGenerator(
                                     rescale=1.0/255.0,
                                     featurewise_center= True,
                                     featurewise_std_normalization = True)
    
    test_it = test_datagen.flow_from_directory('Data/test/',classes =('normal','abnormal'), 
                                               shuffle=False,batch_size=batch_size, target_size=(224, 224))
    
    y_true = test_it.classes;

    y_pred = model.predict_generator(test_it, steps=len(test_it), verbose=1)

    
    y_pred_prob = y_pred[:,1]

     
    y_pred_binary =  y_pred_prob > 0.5
   
    #Confution Matrix    
    print('\nConfusion Matrix\n -------------------------')    
    print(confusion_matrix(y_true,y_pred_binary));
    
    # accuracy: (tp + tn) / (p + n)
    accuracy = accuracy_score(y_true, y_pred_binary)
    print('Accuracy: %f' % accuracy)
    
    
    # precision tp / (tp + fp)
    precision = precision_score(y_true, y_pred_binary)
    print('Precision: %f' % precision)
    
    # recall: tp / (tp + fn)
    recall = recall_score(y_true, y_pred_binary)
    print('Recall: %f' % recall)
    
    # f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(y_true, y_pred_binary)
    print('F1 score: %f' % f1)    
       
    # ROC AUC
    auc = roc_auc_score(y_true, y_pred_prob)
    print('ROC AUC: %f' % auc)
    
    
    # calculate roc curves
    fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
        
    # plot the roc curve for the model
    plt.figure()
    plt_False_Positive_vs_True_Positive.plot(fpr, tpr, linestyle='--', label='')
    
    # axis labels
    plt_False_Positive_vs_True_Positive.xlabel('False Positive Rate')
    plt_False_Positive_vs_True_Positive.ylabel('True Positive Rate')
       
    # show the legend
    plt_False_Positive_vs_True_Positive.legend()
    # show the plot
    plt_False_Positive_vs_True_Positive.show()

# %%
# main entry
    
model = Build_CNN_Model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       608
#
#  activation (Activation)     (None, 224, 224, 8)       0
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 8)       584
#
#  activation_1 (Activation)   (None, 112, 112, 8)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 8)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 16)        1168
#
#  activation_2 (Activation)   (None, 56, 56, 16)        0
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 16)        2320
#
#  activation_3 (Activation)   (None, 56, 56, 16)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 10)                125450
#
#  activation_4 (Activation)   (None, 10)                0
#
#  dense_1 (Dense)             (None, 2)                 22
#
#  activation_5 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 130,152
# Trainable params: 130,152
# Non-trainable params: 0
# _________________________________________________________________

# %%
Train_CNN_Model(model)
# Out:
# Found 600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# C:\Users\STUDEN~1\AppData\Local\Temp/ipykernel_2648/447267304.py:29: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
# C:\Users\Studentlaptops\anaconda3\lib\site-packages\keras_preprocessing\image\image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# C:\Users\Studentlaptops\anaconda3\lib\site-packages\keras_preprocessing\image\image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/100
# 19/19 [==============================] - 49s 3s/step - loss: 0.6861 - accuracy: 0.5600 - val_loss: 0.6264 - val_accuracy: 0.8525
# Epoch 2/100
# 19/19 [==============================] - 50s 3s/step - loss: 0.4982 - accuracy: 0.8133 - val_loss: 0.3239 - val_accuracy: 0.8975
# Epoch 3/100
# 19/19 [==============================] - 48s 3s/step - loss: 0.2728 - accuracy: 0.8833 - val_loss: 0.2347 - val_accuracy: 0.9200
# Epoch 4/100
# 19/19 [==============================] - 47s 2s/step - loss: 0.1657 - accuracy: 0.9400 - val_loss: 0.1884 - val_accuracy: 0.9175
# Epoch 5/100
# 19/19 [==============================] - 46s 2s/step - loss: 0.1018 - accuracy: 0.9650 - val_loss: 0.1697 - val_accuracy: 0.9350
# Epoch 6/100
# 19/19 [==============================] - 64s 3s/step - loss: 0.0724 - accuracy: 0.9750 - val_loss: 0.2965 - val_accuracy: 0.8850
# Epoch 7/100
# 19/19 [==============================] - 72s 4s/step - loss: 0.0818 - accuracy: 0.9700 - val_loss: 0.1479 - val_accuracy: 0.9425
# Epoch 8/100
# 19/19 [==============================] - 69s 4s/step - loss: 0.0623 - accuracy: 0.9700 - val_loss: 0.1377 - val_accuracy: 0.9575
# Epoch 9/100
# 19/19 [==============================] - 70s 4s/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 0.1429 - val_accuracy: 0.9500
# Epoch 10/100
# 19/19 [==============================] - 65s 3s/step - loss: 0.0191 - accuracy: 0.9950 - val_loss: 0.1528 - val_accuracy: 0.9500
# Epoch 11/100
# 19/19 [==============================] - 65s 3s/step - loss: 0.0297 - accuracy: 0.9883 - val_loss: 0.1592 - val_accuracy: 0.9575
# Epoch 12/100
# 19/19 [==============================] - 66s 4s/step - loss: 0.0168 - accuracy: 0.9933 - val_loss: 0.1441 - val_accuracy: 0.9525
# Epoch 13/100
# 19/19 [==============================] - 70s 4s/step - loss: 0.0128 - accuracy: 0.9967 - val_loss: 0.1588 - val_accuracy: 0.9475
# Epoch 14/100
# 19/19 [==============================] - 62s 3s/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.1722 - val_accuracy: 0.9450
# Epoch 15/100
# 19/19 [==============================] - 59s 3s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9600
# Epoch 16/100
# 19/19 [==============================] - 65s 3s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1808 - val_accuracy: 0.9425
# Epoch 17/100
# 19/19 [==============================] - 60s 3s/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.2611 - val_accuracy: 0.9425
# Epoch 18/100
# 19/19 [==============================] - 65s 3s/step - loss: 0.0892 - accuracy: 0.9567 - val_loss: 0.3487 - val_accuracy: 0.9050
# Epoch 19/100
# 19/19 [==============================] - 87s 5s/step - loss: 0.4785 - accuracy: 0.8467 - val_loss: 0.6037 - val_accuracy: 0.8075
# Epoch 20/100
# 19/19 [==============================] - 61s 3s/step - loss: 0.2859 - accuracy: 0.9117 - val_loss: 0.2185 - val_accuracy: 0.9250
# Epoch 21/100
# 19/19 [==============================] - 65s 3s/step - loss: 0.0852 - accuracy: 0.9683 - val_loss: 0.1697 - val_accuracy: 0.9425
# Epoch 22/100
# 19/19 [==============================] - 46s 2s/step - loss: 0.0407 - accuracy: 0.9850 - val_loss: 0.1452 - val_accuracy: 0.9475
# Epoch 23/100
# 19/19 [==============================] - 47s 2s/step - loss: 0.0359 - accuracy: 0.9867 - val_loss: 0.1955 - val_accuracy: 0.9400
# Epoch 24/100
# 19/19 [==============================] - 49s 3s/step - loss: 0.0296 - accuracy: 0.9933 - val_loss: 0.1383 - val_accuracy: 0.9550
# Epoch 25/100
# 19/19 [==============================] - 43s 2s/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 0.1625 - val_accuracy: 0.9475
# Epoch 26/100
# 19/19 [==============================] - 47s 2s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9575
# Epoch 27/100
# 19/19 [==============================] - 43s 2s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9650
# Epoch 28/100
# 19/19 [==============================] - 45s 2s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9650
# Epoch 29/100
# 19/19 [==============================] - 45s 2s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9575
# Epoch 30/100
# 19/19 [==============================] - 45s 2s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.9625
# Epoch 31/100
# 19/19 [==============================] - 204s 2s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9600
# Epoch 32/100
# 19/19 [==============================] - 42s 2s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1767 - val_accuracy: 0.9625
# Epoch 33/100
# 19/19 [==============================] - 42s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9625
# Epoch 34/100
# 19/19 [==============================] - 41s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1715 - val_accuracy: 0.9625
# Epoch 35/100
# 19/19 [==============================] - 43s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9650
# Epoch 36/100
# 19/19 [==============================] - 42s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1872 - val_accuracy: 0.9625
# Epoch 37/100
# 19/19 [==============================] - 152s 8s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1775 - val_accuracy: 0.9625
# Epoch 38/100
# 19/19 [==============================] - 43s 2s/step - loss: 8.9085e-04 - accuracy: 1.0000 - val_loss: 0.1830 - val_accuracy: 0.9625
# Epoch 39/100
# 19/19 [==============================] - 46s 2s/step - loss: 7.3511e-04 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9625
# Epoch 40/100
# 19/19 [==============================] - 46s 2s/step - loss: 7.0215e-04 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9650
# Epoch 41/100
# 19/19 [==============================] - 42s 2s/step - loss: 6.2371e-04 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9600
# Epoch 42/100
# 19/19 [==============================] - 41s 2s/step - loss: 5.5036e-04 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9625
# Epoch 43/100
# 19/19 [==============================] - 41s 2s/step - loss: 5.0699e-04 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9650
# Epoch 44/100
# 19/19 [==============================] - 42s 2s/step - loss: 4.7359e-04 - accuracy: 1.0000 - val_loss: 0.1952 - val_accuracy: 0.9625
# Epoch 45/100
# 19/19 [==============================] - 41s 2s/step - loss: 4.4277e-04 - accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 0.9625
# Epoch 46/100
# 19/19 [==============================] - 42s 2s/step - loss: 4.0314e-04 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9625
# Epoch 47/100
# 19/19 [==============================] - 42s 2s/step - loss: 3.9156e-04 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9650
# Epoch 48/100
# 19/19 [==============================] - 41s 2s/step - loss: 3.8548e-04 - accuracy: 1.0000 - val_loss: 0.2020 - val_accuracy: 0.9625
# Epoch 49/100
# 19/19 [==============================] - 42s 2s/step - loss: 3.5411e-04 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9650
# Epoch 50/100
# 19/19 [==============================] - 41s 2s/step - loss: 3.3123e-04 - accuracy: 1.0000 - val_loss: 0.2077 - val_accuracy: 0.9625
# Epoch 51/100
# 19/19 [==============================] - 41s 2s/step - loss: 3.1714e-04 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9650
# Epoch 52/100
# 19/19 [==============================] - 43s 2s/step - loss: 2.8721e-04 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9650
# Epoch 53/100
# 19/19 [==============================] - 41s 2s/step - loss: 2.8529e-04 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9650
# Epoch 54/100
# 19/19 [==============================] - 557s 31s/step - loss: 2.6841e-04 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9650
# Epoch 55/100
# 19/19 [==============================] - 40s 2s/step - loss: 2.4618e-04 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9675
# Epoch 56/100
# 19/19 [==============================] - 41s 2s/step - loss: 2.3959e-04 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9625
# Epoch 57/100
# 19/19 [==============================] - 42s 2s/step - loss: 2.2858e-04 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9650
# Epoch 58/100
# 19/19 [==============================] - 41s 2s/step - loss: 2.3078e-04 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9650
# Epoch 59/100
# 19/19 [==============================] - 42s 2s/step - loss: 2.0615e-04 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9650
# Epoch 60/100
# 19/19 [==============================] - 42s 2s/step - loss: 2.0354e-04 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9650
# Epoch 61/100
# 19/19 [==============================] - 42s 2s/step - loss: 2.0252e-04 - accuracy: 1.0000 - val_loss: 0.2150 - val_accuracy: 0.9625
# Epoch 62/100
# 19/19 [==============================] - 41s 2s/step - loss: 1.8768e-04 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9650
# Epoch 63/100
# 19/19 [==============================] - 41s 2s/step - loss: 1.7032e-04 - accuracy: 1.0000 - val_loss: 0.2169 - val_accuracy: 0.9625
# Epoch 64/100
# 19/19 [==============================] - 45s 2s/step - loss: 1.6503e-04 - accuracy: 1.0000 - val_loss: 0.2162 - val_accuracy: 0.9650
# Epoch 65/100
# 19/19 [==============================] - 44s 2s/step - loss: 1.5764e-04 - accuracy: 1.0000 - val_loss: 0.2164 - val_accuracy: 0.9650
# Epoch 66/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.5523e-04 - accuracy: 1.0000 - val_loss: 0.2184 - val_accuracy: 0.9650
# Epoch 67/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.5080e-04 - accuracy: 1.0000 - val_loss: 0.2174 - val_accuracy: 0.9675
# Epoch 68/100
# 19/19 [==============================] - 45s 2s/step - loss: 1.4084e-04 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9600
# Epoch 69/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.3383e-04 - accuracy: 1.0000 - val_loss: 0.2179 - val_accuracy: 0.9675
# Epoch 70/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.3502e-04 - accuracy: 1.0000 - val_loss: 0.2193 - val_accuracy: 0.9650
# Epoch 71/100
# 19/19 [==============================] - 43s 2s/step - loss: 1.3055e-04 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9650
# Epoch 72/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.2437e-04 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9650
# Epoch 73/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.1771e-04 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9650
# Epoch 74/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.1482e-04 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9675
# Epoch 75/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.1257e-04 - accuracy: 1.0000 - val_loss: 0.2246 - val_accuracy: 0.9650
# Epoch 76/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.1357e-04 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9625
# Epoch 77/100
# 19/19 [==============================] - 42s 2s/step - loss: 1.0572e-04 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9675
# Epoch 78/100
# 19/19 [==============================] - 41s 2s/step - loss: 9.9807e-05 - accuracy: 1.0000 - val_loss: 0.2272 - val_accuracy: 0.9650
# Epoch 79/100
# 19/19 [==============================] - 370s 20s/step - loss: 9.9315e-05 - accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9675
# Epoch 80/100
# 19/19 [==============================] - 42s 2s/step - loss: 9.8392e-05 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9650
# Epoch 81/100
# 19/19 [==============================] - 44s 2s/step - loss: 9.3992e-05 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9650
# Epoch 82/100
# 19/19 [==============================] - 41s 2s/step - loss: 8.9920e-05 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9675
# Epoch 83/100
# 19/19 [==============================] - 41s 2s/step - loss: 8.8567e-05 - accuracy: 1.0000 - val_loss: 0.2284 - val_accuracy: 0.9675
# Epoch 84/100
# 19/19 [==============================] - 43s 2s/step - loss: 8.4680e-05 - accuracy: 1.0000 - val_loss: 0.2289 - val_accuracy: 0.9675
# Epoch 85/100
# 19/19 [==============================] - 43s 2s/step - loss: 8.3857e-05 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9675
# Epoch 86/100
# 19/19 [==============================] - 34s 2s/step - loss: 8.0100e-05 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9675
# Epoch 87/100
# 19/19 [==============================] - 39s 2s/step - loss: 8.0560e-05 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9675
# Epoch 88/100
# 19/19 [==============================] - 45s 2s/step - loss: 7.4419e-05 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9675
# Epoch 89/100
# 19/19 [==============================] - 24s 1s/step - loss: 7.4581e-05 - accuracy: 1.0000 - val_loss: 0.2326 - val_accuracy: 0.9675
# Epoch 90/100
# 19/19 [==============================] - 26s 1s/step - loss: 7.0835e-05 - accuracy: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.9675
# Epoch 91/100
# 19/19 [==============================] - 26s 1s/step - loss: 6.9284e-05 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9650
# Epoch 92/100
# 19/19 [==============================] - 25s 1s/step - loss: 6.7833e-05 - accuracy: 1.0000 - val_loss: 0.2341 - val_accuracy: 0.9675
# Epoch 93/100
# 19/19 [==============================] - 25s 1s/step - loss: 6.5812e-05 - accuracy: 1.0000 - val_loss: 0.2341 - val_accuracy: 0.9675
# Epoch 94/100
# 19/19 [==============================] - 24s 1s/step - loss: 6.4919e-05 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.9675
# Epoch 95/100
# 19/19 [==============================] - 25s 1s/step - loss: 6.3731e-05 - accuracy: 1.0000 - val_loss: 0.2373 - val_accuracy: 0.9650
# Epoch 96/100
# 19/19 [==============================] - 25s 1s/step - loss: 6.2085e-05 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.9675
# Epoch 97/100
# 19/19 [==============================] - 25s 1s/step - loss: 5.8297e-05 - accuracy: 1.0000 - val_loss: 0.2384 - val_accuracy: 0.9675
# Epoch 98/100
# 19/19 [==============================] - 25s 1s/step - loss: 5.7289e-05 - accuracy: 1.0000 - val_loss: 0.2379 - val_accuracy: 0.9675
# Epoch 99/100
# 19/19 [==============================] - 25s 1s/step - loss: 5.7366e-05 - accuracy: 1.0000 - val_loss: 0.2393 - val_accuracy: 0.9650
# Epoch 100/100
# 19/19 [==============================] - 26s 1s/step - loss: 5.4760e-05 - accuracy: 1.0000 - val_loss: 0.2380 - val_accuracy: 0.9675

# %%
Evaluate_CNN_Model()
# Out:
# Found 624 images belonging to 2 classes.
# C:\Users\STUDEN~1\AppData\Local\Temp/ipykernel_2648/1273337992.py:21: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(test_it, steps=len(test_it), verbose=1)
# 20/20 [==============================] - 10s 463ms/step
# No handles with labels found to put in legend.
# Confusion Matrix
#  -------------------------
# [[120 114]
#  [ 11 379]]
# Accuracy: 0.799679
# Precision: 0.768763
# Recall: 0.971795
# F1 score: 0.858437
# ROC AUC: 0.901008

# %%
m = [[120, 114],
 [ 11, 379]]

# %%
m
# Out:
# [[120, 114], [11, 379]]

# %%
import seaborn as sns

ax = sns.heatmap(m, annot=True, cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()
