# %%
from keras.models import Sequential,load_model
from keras.layers import Conv2D,Activation, MaxPooling2D,Dense,Flatten
#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score,roc_curve,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt_False_Positive_vs_True_Positive

# %%
def Build_CNN_Model():
    
    # -------------------------------------------------------------------------
    #                        Build CNN Model 
    # -------------------------------------------------------------------------
    model = Sequential()
    
    #  First Block of CNN
    model.add(Conv2D(8, (5, 5), padding='same', input_shape=(224, 224, 3)))  
    model.add(Activation('relu'))
    model.add(MaxPooling2D((2, 2)))
    
    #  Second Block of CNN
    model.add(Conv2D(8, (3, 3),  padding='same'))  
    model.add(Activation('relu'))
    model.add(MaxPooling2D((2, 2)))

    #  Third Block of CNN
    model.add(Conv2D(16, (3, 3),  padding='same'))  
    model.add(Activation('relu'))


    #  Forth Block of CNN
    model.add(Conv2D(16, (3, 3),  padding='same'))  
    model.add(Activation('relu'))
    model.add(MaxPooling2D((2, 2)))

    
    #  Flatten and Fully Connected Layer
    model.add(Flatten())
    model.add(Dense(10))
    model.add(Activation('relu'))
     
    #  Softmax Classifier
    model.add(Dense(2))
    model.add(Activation('softmax'))
        
    #  Display model
    model.summary()
    
	# compile model

    opt = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# train and evalluate cnn model
def Train_CNN_Model(model):
    
    # -------------------------------------------------------------------------
    #                        Train CNN Model 
    # -------------------------------------------------------------------------
    
    
    # create data generators    
    train_datagen = ImageDataGenerator(
                                     rescale=1.0/255.0,
                                     featurewise_center= True,
                                     featurewise_std_normalization = True,
                                     rotation_range=10,
                                     width_shift_range=0.1,
                                     height_shift_range=0.1,
                                     zoom_range=0.2,                                     
                                     brightness_range=[0.2,1.0],
                                     )
    
    valid_datagen = ImageDataGenerator(
                                     rescale=1.0/255.0,
                                     featurewise_center= True,
                                     featurewise_std_normalization = True)
    
  
   
    # prepare iterators
    batch_size=32
    train_it = train_datagen.flow_from_directory('Data/train/',classes =('normal','abnormal'),batch_size=batch_size, target_size=(224, 224))
    valid_it = valid_datagen.flow_from_directory('Data/val/',classes =('normal','abnormal'),batch_size=batch_size, target_size=(224, 224))


    epochs=100;
    
    history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
		validation_data=valid_it, validation_steps=len(valid_it), epochs=epochs, verbose=1)
    
    
    #  "Accuracy"
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
    # "Loss"
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

	# save model
    model.save('medical_diagnosis_cnn_model.h5')

# %%
def Evaluate_CNN_Model():
    # -------------------------------------------------------------------------
    #                        Evaluate CNN Model 
    # -------------------------------------------------------------------------
    
    # load model
    model = load_model('medical_diagnosis_cnn_model.h5')
    
    # load test data
    batch_size=32
    test_datagen = ImageDataGenerator(
                                     rescale=1.0/255.0,
                                     featurewise_center= True,
                                     featurewise_std_normalization = True)
    
    test_it = test_datagen.flow_from_directory('Data/test/',classes =('normal','abnormal'), 
                                               shuffle=False,batch_size=batch_size, target_size=(224, 224))
    
    y_true = test_it.classes;

    y_pred = model.predict_generator(test_it, steps=len(test_it), verbose=1)

    
    y_pred_prob = y_pred[:,1]

     
    y_pred_binary =  y_pred_prob > 0.5
   
    #Confution Matrix    
    print('\nConfusion Matrix\n -------------------------')    
    print(confusion_matrix(y_true,y_pred_binary));
    
    # accuracy: (tp + tn) / (p + n)
    accuracy = accuracy_score(y_true, y_pred_binary)
    print('Accuracy: %f' % accuracy)
    
    
    # precision tp / (tp + fp)
    precision = precision_score(y_true, y_pred_binary)
    print('Precision: %f' % precision)
    
    # recall: tp / (tp + fn)
    recall = recall_score(y_true, y_pred_binary)
    print('Recall: %f' % recall)
    
    # f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(y_true, y_pred_binary)
    print('F1 score: %f' % f1)    
       
    # ROC AUC
    auc = roc_auc_score(y_true, y_pred_prob)
    print('ROC AUC: %f' % auc)
    
    
    # calculate roc curves
    fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
        
    # plot the roc curve for the model
    plt.figure()
    plt_False_Positive_vs_True_Positive.plot(fpr, tpr, linestyle='--', label='')
    
    # axis labels
    plt_False_Positive_vs_True_Positive.xlabel('False Positive Rate')
    plt_False_Positive_vs_True_Positive.ylabel('True Positive Rate')
       
    # show the legend
    plt_False_Positive_vs_True_Positive.legend()
    # show the plot
    plt_False_Positive_vs_True_Positive.show()

# %%
# main entry
    
model = Build_CNN_Model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       608
#
#  activation (Activation)     (None, 224, 224, 8)       0
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 8)       584
#
#  activation_1 (Activation)   (None, 112, 112, 8)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 8)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 16)        1168
#
#  activation_2 (Activation)   (None, 56, 56, 16)        0
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 16)        2320
#
#  activation_3 (Activation)   (None, 56, 56, 16)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 10)                125450
#
#  activation_4 (Activation)   (None, 10)                0
#
#  dense_1 (Dense)             (None, 2)                 22
#
#  activation_5 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 130,152
# Trainable params: 130,152
# Non-trainable params: 0
# _________________________________________________________________

# %%
Train_CNN_Model(model)
# Out:
# Found 600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# C:\Users\STUDEN~1\AppData\Local\Temp/ipykernel_24112/3292953681.py:36: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
# Epoch 1/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.2158 - accuracy: 0.9233 - val_loss: 0.1608 - val_accuracy: 0.9400
# Epoch 2/100
# 19/19 [==============================] - 30s 2s/step - loss: 0.2947 - accuracy: 0.8767 - val_loss: 0.2335 - val_accuracy: 0.9175
# Epoch 3/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.2874 - accuracy: 0.8950 - val_loss: 0.1892 - val_accuracy: 0.9225
# Epoch 4/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.3002 - accuracy: 0.8967 - val_loss: 0.2192 - val_accuracy: 0.9175
# Epoch 5/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.2179 - accuracy: 0.9217 - val_loss: 0.3390 - val_accuracy: 0.9050
# Epoch 6/100
# 19/19 [==============================] - 34s 2s/step - loss: 0.2339 - accuracy: 0.9117 - val_loss: 0.2707 - val_accuracy: 0.9125
# Epoch 7/100
# 19/19 [==============================] - 47s 3s/step - loss: 0.3100 - accuracy: 0.8650 - val_loss: 0.2514 - val_accuracy: 0.9050
# Epoch 8/100
# 19/19 [==============================] - 36s 2s/step - loss: 0.2721 - accuracy: 0.9000 - val_loss: 0.2113 - val_accuracy: 0.9150
# Epoch 9/100
# 19/19 [==============================] - 40s 2s/step - loss: 0.2209 - accuracy: 0.9217 - val_loss: 0.1756 - val_accuracy: 0.9375
# Epoch 10/100
# 19/19 [==============================] - 33s 2s/step - loss: 0.2712 - accuracy: 0.8850 - val_loss: 0.1862 - val_accuracy: 0.9250
# Epoch 11/100
# 19/19 [==============================] - 34s 2s/step - loss: 0.2481 - accuracy: 0.9117 - val_loss: 0.1954 - val_accuracy: 0.9375
# Epoch 12/100
# 19/19 [==============================] - 38s 2s/step - loss: 0.1944 - accuracy: 0.9200 - val_loss: 0.2697 - val_accuracy: 0.9250
# Epoch 13/100
# 19/19 [==============================] - 43s 2s/step - loss: 0.2421 - accuracy: 0.9000 - val_loss: 0.1906 - val_accuracy: 0.9225
# Epoch 14/100
# 19/19 [==============================] - 59s 3s/step - loss: 0.2801 - accuracy: 0.8950 - val_loss: 0.2976 - val_accuracy: 0.9000
# Epoch 15/100
# 19/19 [==============================] - 85s 4s/step - loss: 0.2445 - accuracy: 0.9150 - val_loss: 0.2282 - val_accuracy: 0.9250
# Epoch 16/100
# 19/19 [==============================] - 86s 4s/step - loss: 0.2099 - accuracy: 0.9300 - val_loss: 0.3310 - val_accuracy: 0.9000
# Epoch 17/100
# 19/19 [==============================] - 84s 4s/step - loss: 0.2491 - accuracy: 0.9017 - val_loss: 0.1743 - val_accuracy: 0.9375
# Epoch 18/100
# 19/19 [==============================] - 83s 4s/step - loss: 0.2575 - accuracy: 0.9000 - val_loss: 0.1462 - val_accuracy: 0.9450
# Epoch 19/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.2708 - accuracy: 0.9100 - val_loss: 0.1761 - val_accuracy: 0.9325
# Epoch 20/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.2047 - accuracy: 0.9267 - val_loss: 0.1583 - val_accuracy: 0.9400
# Epoch 21/100
# 19/19 [==============================] - 81s 4s/step - loss: 0.2468 - accuracy: 0.9033 - val_loss: 0.1935 - val_accuracy: 0.9300
# Epoch 22/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.2341 - accuracy: 0.9117 - val_loss: 0.3304 - val_accuracy: 0.9000
# Epoch 23/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.2232 - accuracy: 0.9033 - val_loss: 0.1849 - val_accuracy: 0.9350
# Epoch 24/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.2167 - accuracy: 0.9133 - val_loss: 0.2378 - val_accuracy: 0.9300
# Epoch 25/100
# 19/19 [==============================] - 81s 4s/step - loss: 0.1771 - accuracy: 0.9317 - val_loss: 0.2000 - val_accuracy: 0.9250
# Epoch 26/100
# 19/19 [==============================] - 94s 5s/step - loss: 0.2120 - accuracy: 0.9233 - val_loss: 0.3110 - val_accuracy: 0.9075
# Epoch 27/100
# 19/19 [==============================] - 95s 5s/step - loss: 0.2124 - accuracy: 0.9150 - val_loss: 0.2109 - val_accuracy: 0.9275
# Epoch 28/100
# 19/19 [==============================] - 94s 5s/step - loss: 0.1922 - accuracy: 0.9383 - val_loss: 0.4096 - val_accuracy: 0.8950
# Epoch 29/100
# 19/19 [==============================] - 94s 5s/step - loss: 0.2035 - accuracy: 0.9367 - val_loss: 0.1967 - val_accuracy: 0.9400
# Epoch 30/100
# 19/19 [==============================] - 88s 5s/step - loss: 0.1951 - accuracy: 0.9267 - val_loss: 0.2747 - val_accuracy: 0.9200
# Epoch 31/100
# 19/19 [==============================] - 86s 4s/step - loss: 0.2397 - accuracy: 0.9117 - val_loss: 0.1985 - val_accuracy: 0.9275
# Epoch 32/100
# 19/19 [==============================] - 3617s 201s/step - loss: 0.2237 - accuracy: 0.9233 - val_loss: 0.1963 - val_accuracy: 0.9300
# Epoch 33/100
# 19/19 [==============================] - 113s 6s/step - loss: 0.1792 - accuracy: 0.9333 - val_loss: 0.2582 - val_accuracy: 0.9325
# Epoch 34/100
# 19/19 [==============================] - 94s 5s/step - loss: 0.1861 - accuracy: 0.9333 - val_loss: 0.2091 - val_accuracy: 0.9275
# Epoch 35/100
# 19/19 [==============================] - 83s 5s/step - loss: 0.1885 - accuracy: 0.9367 - val_loss: 0.2631 - val_accuracy: 0.9300
# Epoch 36/100
# 19/19 [==============================] - 84s 4s/step - loss: 0.2000 - accuracy: 0.9283 - val_loss: 0.2199 - val_accuracy: 0.9250
# Epoch 37/100
# 19/19 [==============================] - 84s 5s/step - loss: 0.2037 - accuracy: 0.9233 - val_loss: 0.2095 - val_accuracy: 0.9275
# Epoch 38/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.1892 - accuracy: 0.9300 - val_loss: 0.2844 - val_accuracy: 0.9225
# Epoch 39/100
# 19/19 [==============================] - 81s 4s/step - loss: 0.1920 - accuracy: 0.9283 - val_loss: 0.2129 - val_accuracy: 0.9275
# Epoch 40/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.1767 - accuracy: 0.9450 - val_loss: 0.2040 - val_accuracy: 0.9350
# Epoch 41/100
# 19/19 [==============================] - 863s 48s/step - loss: 0.1953 - accuracy: 0.9167 - val_loss: 0.2180 - val_accuracy: 0.9325
# Epoch 42/100
# 19/19 [==============================] - 81s 4s/step - loss: 0.2282 - accuracy: 0.9133 - val_loss: 0.2493 - val_accuracy: 0.9200
# Epoch 43/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.1614 - accuracy: 0.9483 - val_loss: 0.1924 - val_accuracy: 0.9300
# Epoch 44/100
# 19/19 [==============================] - 84s 4s/step - loss: 0.2041 - accuracy: 0.9283 - val_loss: 0.3385 - val_accuracy: 0.9150
# Epoch 45/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.1663 - accuracy: 0.9450 - val_loss: 0.3042 - val_accuracy: 0.9175
# Epoch 46/100
# 19/19 [==============================] - 78s 4s/step - loss: 0.1927 - accuracy: 0.9283 - val_loss: 0.2317 - val_accuracy: 0.9250
# Epoch 47/100
# 19/19 [==============================] - 78s 4s/step - loss: 0.1980 - accuracy: 0.9200 - val_loss: 0.1801 - val_accuracy: 0.9325
# Epoch 48/100
# 19/19 [==============================] - 77s 4s/step - loss: 0.1696 - accuracy: 0.9450 - val_loss: 0.3318 - val_accuracy: 0.9200
# Epoch 49/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.1937 - accuracy: 0.9300 - val_loss: 0.1775 - val_accuracy: 0.9275
# Epoch 50/100
# 19/19 [==============================] - 77s 4s/step - loss: 0.1636 - accuracy: 0.9367 - val_loss: 0.2299 - val_accuracy: 0.9250
# Epoch 51/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.2028 - accuracy: 0.9283 - val_loss: 0.1855 - val_accuracy: 0.9250
# Epoch 52/100
# 19/19 [==============================] - 519s 29s/step - loss: 0.1707 - accuracy: 0.9250 - val_loss: 0.2121 - val_accuracy: 0.9500
# Epoch 53/100
# 19/19 [==============================] - 84s 4s/step - loss: 0.1552 - accuracy: 0.9383 - val_loss: 0.2751 - val_accuracy: 0.9275
# Epoch 54/100
# 19/19 [==============================] - 84s 4s/step - loss: 0.1688 - accuracy: 0.9433 - val_loss: 0.2361 - val_accuracy: 0.9325
# Epoch 55/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.1646 - accuracy: 0.9350 - val_loss: 0.3302 - val_accuracy: 0.9100
# Epoch 56/100
# 19/19 [==============================] - 77s 4s/step - loss: 0.2080 - accuracy: 0.9150 - val_loss: 0.2283 - val_accuracy: 0.9350
# Epoch 57/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.1948 - accuracy: 0.9333 - val_loss: 0.2664 - val_accuracy: 0.9150
# Epoch 58/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.1691 - accuracy: 0.9317 - val_loss: 0.2566 - val_accuracy: 0.9250
# Epoch 59/100
# 19/19 [==============================] - 483s 27s/step - loss: 0.2118 - accuracy: 0.9133 - val_loss: 0.2879 - val_accuracy: 0.8875
# Epoch 60/100
# 19/19 [==============================] - 83s 4s/step - loss: 0.2177 - accuracy: 0.8983 - val_loss: 0.1754 - val_accuracy: 0.9425
# Epoch 61/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.1962 - accuracy: 0.9283 - val_loss: 0.3006 - val_accuracy: 0.9125
# Epoch 62/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.1894 - accuracy: 0.9367 - val_loss: 0.2212 - val_accuracy: 0.9200
# Epoch 63/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.1928 - accuracy: 0.9233 - val_loss: 0.2269 - val_accuracy: 0.9325
# Epoch 64/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.1798 - accuracy: 0.9250 - val_loss: 0.1531 - val_accuracy: 0.9450
# Epoch 65/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.2272 - accuracy: 0.9083 - val_loss: 0.2008 - val_accuracy: 0.9325
# Epoch 66/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.1757 - accuracy: 0.9317 - val_loss: 0.1665 - val_accuracy: 0.9475
# Epoch 67/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.1877 - accuracy: 0.9233 - val_loss: 0.2197 - val_accuracy: 0.9325
# Epoch 68/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.2168 - accuracy: 0.9167 - val_loss: 0.2828 - val_accuracy: 0.9125
# Epoch 69/100
# 19/19 [==============================] - 82s 4s/step - loss: 0.1652 - accuracy: 0.9383 - val_loss: 0.3406 - val_accuracy: 0.9100
# Epoch 70/100
# 19/19 [==============================] - 78s 4s/step - loss: 0.1820 - accuracy: 0.9283 - val_loss: 0.2422 - val_accuracy: 0.9150
# Epoch 71/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.1634 - accuracy: 0.9333 - val_loss: 0.2180 - val_accuracy: 0.9325
# Epoch 72/100
# 19/19 [==============================] - 77s 4s/step - loss: 0.1572 - accuracy: 0.9400 - val_loss: 0.2017 - val_accuracy: 0.9200
# Epoch 73/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.1818 - accuracy: 0.9333 - val_loss: 0.1648 - val_accuracy: 0.9375
# Epoch 74/100
# 19/19 [==============================] - 1451s 80s/step - loss: 0.1516 - accuracy: 0.9433 - val_loss: 0.2160 - val_accuracy: 0.9225
# Epoch 75/100
# 19/19 [==============================] - 47s 2s/step - loss: 0.1271 - accuracy: 0.9517 - val_loss: 0.1872 - val_accuracy: 0.9400
# Epoch 76/100
# 19/19 [==============================] - 84s 4s/step - loss: 0.1485 - accuracy: 0.9383 - val_loss: 0.1926 - val_accuracy: 0.9300
# Epoch 77/100
# 19/19 [==============================] - 81s 4s/step - loss: 0.1685 - accuracy: 0.9383 - val_loss: 0.2654 - val_accuracy: 0.9200
# Epoch 78/100
# 19/19 [==============================] - 83s 4s/step - loss: 0.2060 - accuracy: 0.9183 - val_loss: 0.1872 - val_accuracy: 0.9325
# Epoch 79/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.1660 - accuracy: 0.9400 - val_loss: 0.2939 - val_accuracy: 0.9200
# Epoch 80/100
# 19/19 [==============================] - 116s 6s/step - loss: 0.1323 - accuracy: 0.9417 - val_loss: 0.2274 - val_accuracy: 0.9375
# Epoch 81/100
# 19/19 [==============================] - 2884s 160s/step - loss: 0.1692 - accuracy: 0.9183 - val_loss: 0.1741 - val_accuracy: 0.9325
# Epoch 82/100
# 19/19 [==============================] - 79s 4s/step - loss: 0.1616 - accuracy: 0.9267 - val_loss: 0.1832 - val_accuracy: 0.9300
# Epoch 83/100
# 19/19 [==============================] - 80s 4s/step - loss: 0.1967 - accuracy: 0.9117 - val_loss: 0.2858 - val_accuracy: 0.9125
# Epoch 84/100
# 19/19 [==============================] - 77s 4s/step - loss: 0.1599 - accuracy: 0.9383 - val_loss: 0.2861 - val_accuracy: 0.9275
# Epoch 85/100
# 19/19 [==============================] - 76s 4s/step - loss: 0.1836 - accuracy: 0.9233 - val_loss: 0.1783 - val_accuracy: 0.9250
# Epoch 86/100
# 19/19 [==============================] - 75s 4s/step - loss: 0.1355 - accuracy: 0.9450 - val_loss: 0.2193 - val_accuracy: 0.9300
# Epoch 87/100
# 19/19 [==============================] - 74s 4s/step - loss: 0.1499 - accuracy: 0.9467 - val_loss: 0.2782 - val_accuracy: 0.9225
# Epoch 88/100
# 19/19 [==============================] - 74s 4s/step - loss: 0.1701 - accuracy: 0.9317 - val_loss: 0.2546 - val_accuracy: 0.9275
# Epoch 89/100
# 19/19 [==============================] - 879s 49s/step - loss: 0.1393 - accuracy: 0.9467 - val_loss: 0.1784 - val_accuracy: 0.9275
# Epoch 90/100
# 19/19 [==============================] - 74s 4s/step - loss: 0.1377 - accuracy: 0.9467 - val_loss: 0.1934 - val_accuracy: 0.9350
# Epoch 91/100
# 19/19 [==============================] - 74s 4s/step - loss: 0.1675 - accuracy: 0.9350 - val_loss: 0.2181 - val_accuracy: 0.9275
# Epoch 92/100
# 19/19 [==============================] - 75s 4s/step - loss: 0.1347 - accuracy: 0.9483 - val_loss: 0.1900 - val_accuracy: 0.9300
# Epoch 93/100
# 19/19 [==============================] - 73s 4s/step - loss: 0.1602 - accuracy: 0.9367 - val_loss: 0.1779 - val_accuracy: 0.9225
# Epoch 94/100
# 19/19 [==============================] - 74s 4s/step - loss: 0.1398 - accuracy: 0.9550 - val_loss: 0.2166 - val_accuracy: 0.9175
# Epoch 95/100
# 19/19 [==============================] - 74s 4s/step - loss: 0.1656 - accuracy: 0.9417 - val_loss: 0.1569 - val_accuracy: 0.9300
# Epoch 96/100
# 19/19 [==============================] - 74s 4s/step - loss: 0.1602 - accuracy: 0.9317 - val_loss: 0.1687 - val_accuracy: 0.9400
# Epoch 97/100
# 19/19 [==============================] - 74s 4s/step - loss: 0.1524 - accuracy: 0.9433 - val_loss: 0.2010 - val_accuracy: 0.9225
# Epoch 98/100
# 19/19 [==============================] - 1281s 71s/step - loss: 0.1572 - accuracy: 0.9300 - val_loss: 0.2431 - val_accuracy: 0.9250
# Epoch 99/100
# 19/19 [==============================] - 74s 4s/step - loss: 0.2046 - accuracy: 0.9217 - val_loss: 0.1699 - val_accuracy: 0.9225
# Epoch 100/100
# 19/19 [==============================] - 76s 4s/step - loss: 0.1565 - accuracy: 0.9417 - val_loss: 0.1642 - val_accuracy: 0.9375

# %%
Evaluate_CNN_Model()
# Out:
# Found 624 images belonging to 2 classes.
# C:\Users\STUDEN~1\AppData\Local\Temp/ipykernel_24112/920839411.py:21: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(test_it, steps=len(test_it), verbose=1)
# 20/20 [==============================] - 26s 1s/step
# No handles with labels found to put in legend.
# Confusion Matrix
#  -------------------------
# [[150  84]
#  [ 12 378]]
# Accuracy: 0.846154
# Precision: 0.818182
# Recall: 0.969231
# F1 score: 0.887324
# ROC AUC: 0.933235
